# %%
import pandas as pd

# %%
df=pd.read_csv('titanic_dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\91750\anaconda3\lib\site-packages (from pandas-profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\91750\anaconda3\lib\site-packages (from pandas-profiling) (2.1.4)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\91750\anaconda3\lib\site-packages (from pandas-profiling) (3.8.0)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\91750\anaconda3\lib\site-packages (from pandas-profiling) (1.10.12)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\91750\anaconda3\lib\site-packages (from pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\91750\anaconda3\lib\site-packages (from pandas-profiling) (3.1.3)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\91750\anaconda3\lib\site-packages (from pandas-profiling) (2.1.3)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\91750\anaconda3\lib\site-packages (from pandas-profiling) (1.26.4)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Downloading phik-0.12.4-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\91750\anaconda3\lib\site-packages (from pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\91750\anaconda3\lib\site-packages (from pandas-profiling) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\91750\anaconda3\lib\site-packages (from pandas-profiling) (0.12.2)
# Collecting multimethod>=1.4 (from pandas-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\91750\anaconda3\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\91750\anaconda3\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.1)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: Pillow in c:\users\91750\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91750\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\91750\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\91750\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91750\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91750\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91750\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91750\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\91750\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\91750\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\91750\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.5.0)
# Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
#    ---------------------------------------- 0.0/262.6 kB ? eta -:--:--
#    --------------------------------------- 262.6/262.6 kB 15.8 MB/s eta 0:00:00
# Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/4.7 MB 14.9 MB/s eta 0:00:01
#    -------- ------------------------------- 1.0/4.7 MB 12.6 MB/s eta 0:00:01
#    ------------ --------------------------- 1.5/4.7 MB 12.0 MB/s eta 0:00:01
#    --------------- ------------------------ 1.8/4.7 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 2.3/4.7 MB 10.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.8/4.7 MB 10.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.3/4.7 MB 11.2 MB/s eta 0:00:01
#    -------------------------------- ------- 3.9/4.7 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------- -- 4.4/4.7 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 10.8 MB/s eta 0:00:00
# Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#    ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#    ---------------------------------------- 102.4/102.4 kB 6.1 MB/s eta 0:00:00
# Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
#    ---------------------------------------- 0.0/309.8 kB ? eta -:--:--
#    ---------------------------------------- 309.8/309.8 kB 9.4 MB/s eta 0:00:00
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.4-cp311-cp311-win_amd64.whl (667 kB)
#    ---------------------------------------- 0.0/667.1 kB ? eta -:--:--
#    ----------------------------- --------- 501.8/667.1 kB 10.5 MB/s eta 0:00:01
#    --------------------------------------- 667.1/667.1 kB 10.4 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ---------------------------------------- 0.0/296.5 kB ? eta -:--:--
#    ---------------------------------------- 296.5/296.5 kB 6.1 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27091 sha256=beaae578ccf57d8a4af7c7652add41255c74101a762f172f0439c16e41d69199
#   Stored in directory: c:\users\91750\appdata\local\pip\cache\wheels\8d\55\1a\19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: htmlmin, tangled-up-in-unicode, multimethod, joblib, imagehash, visions, phik, missingno, pandas-profiling
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
# Successfully installed htmlmin-0.1.12 imagehash-4.3.1 joblib-1.1.1 missingno-0.5.2 multimethod-1.12 pandas-profiling-3.2.0 phik-0.12.4 tangled-up-in-unicode-0.2.0 visions-0.7.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from ydata_profiling import ProfileReport


profile = ProfileReport(df, title="Profiling Report")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#       5 profile = ProfileReport(df, title="Profiling Report")
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
pip install ydata_profiling
# Out:
# Collecting ydata_profiling
#   Downloading ydata_profiling-4.9.0-py2.py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (2.1.4)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (3.8.0)
# Collecting pydantic>=2 (from ydata_profiling)
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      -------------------------------------  122.9/125.2 kB 2.4 MB/s eta 0:00:01
#      -------------------------------------- 125.2/125.2 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (3.1.3)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling)
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2,>=1.16.0 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (4.65.0)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (0.14.0)
# Collecting typeguard<5,>=3 (from ydata_profiling)
#   Downloading typeguard-4.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (4.3.1)
# Collecting wordcloud>=1.9.1 (from ydata_profiling)
#   Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite>=1.8 (from ydata_profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numba<1,>=0.56.0 in c:\users\91750\anaconda3\lib\site-packages (from ydata_profiling) (0.59.0)
# Requirement already satisfied: PyWavelets in c:\users\91750\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata_profiling) (1.5.0)
# Requirement already satisfied: pillow in c:\users\91750\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata_profiling) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91750\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91750\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\91750\anaconda3\lib\site-packages (from numba<1,>=0.56.0->ydata_profiling) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91750\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\91750\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\91750\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.1.1)
# Collecting annotated-types>=0.4.0 (from pydantic>=2->ydata_profiling)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic>=2->ydata_profiling)
#   Downloading pydantic_core-2.20.1-cp311-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\91750\anaconda3\lib\site-packages (from pydantic>=2->ydata_profiling) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91750\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91750\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91750\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91750\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2024.2.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\91750\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (0.5.3)
# Requirement already satisfied: colorama in c:\users\91750\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata_profiling) (0.4.6)
# Collecting typing-extensions>=4.6.1 (from pydantic>=2->ydata_profiling)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\91750\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\91750\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (3.1)
# Requirement already satisfied: six in c:\users\91750\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata_profiling) (1.16.0)
# Downloading ydata_profiling-4.9.0-py2.py3-none-any.whl (356 kB)
#    ---------------------------------------- 0.0/356.2 kB ? eta -:--:--
#    -------------------------------- ------- 286.7/356.2 kB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 356.2/356.2 kB 7.5 MB/s eta 0:00:00
# Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ---------------------------------------- 0.0/423.9 kB ? eta -:--:--
#    -------------------------------------- - 409.6/423.9 kB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 423.9/423.9 kB 8.8 MB/s eta 0:00:00
# Downloading pydantic_core-2.20.1-cp311-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.9 MB 11.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.1/1.9 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 10.1 MB/s eta 0:00:00
# Downloading typeguard-4.3.0-py3-none-any.whl (35 kB)
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#    ---------------------------------------- 0.0/104.8 kB ? eta -:--:--
#    ---------------------------------------- 104.8/104.8 kB ? eta 0:00:00
# Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    ---------------------------------------- 300.2/300.2 kB 9.4 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, dacite, annotated-types, typeguard, pydantic-core, wordcloud, visions, pydantic, ydata_profiling
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.12
#     Uninstalling pydantic-1.10.12:
#       Successfully uninstalled pydantic-1.10.12
# Successfully installed annotated-types-0.7.0 dacite-1.8.1 pydantic-2.8.2 pydantic-core-2.20.1 typeguard-4.3.0 typing-extensions-4.12.2 visions-0.7.6 wordcloud-1.9.3 ydata_profiling-4.9.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-cloud-auth 0.1.4 requires pydantic<2.0, but you have pydantic 2.8.2 which is incompatible.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.

# %%
import pandas as pd
from ydata_profiling import ProfileReport


profile = ProfileReport(df, title="Profiling Report")
